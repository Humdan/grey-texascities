# %%
import numpy as np
import pandas as pd
allData = pd.read_csv('resources/texas-cities.csv', delimiter = ',',names=['name', '2010', '2011', '2012', '2013', '2014', '2015', '2016', '2017'])

# %%
allData
# Out:
#                            name    2010    2011    2012    2013    2014  \
# 0                          name    2010    2011    2012    2013    2014
# 1            Abbott city, Texas     361     362     361     357     354
# 2         Abernathy city, Texas    2824    2839    2827    2802    2748
# 3           Abilene city, Texas  117807  118764  119852  119745  120450
# 4           Ackerly city, Texas     220     219     219     224     228
# 5           Addison town, Texas   13091   13795   15187   15424   15475
# 6            Adrian city, Texas     166     167     164     168     166
# 7        Agua Dulce city, Texas     811     812     819     823     820
# 8             Alamo city, Texas   18586   18813   18990   19133   19307
# 9     Alamo Heights city, Texas    7048    7176    7329    7526    7758
# 10             Alba town, Texas     502     504     502     504     508
# 11           Albany city, Texas    2038    1998    2013    2020    1986
# ...
